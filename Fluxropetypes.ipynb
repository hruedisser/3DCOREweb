# %% [markdown]
# # Fluxrope types
#
# This notebook shows different fluxrope types according to Mulligan, T., Russell, C. T., & Luhmann, J. G. 1998, Geophys. Rev. Lett., 25, 2959

# %%
# %load_ext autoreload

# %autoreload 2

# import packages
from coreweb.methods.offwebutils import get_modelkwargs_ranges, offwebfit, get_eventinfo, update_posfig_offweb, create_movie, ropeplotter, allropeplotter
from coreweb.dashcore.utils.plotting import check_animation, check_fittingpoints, get_longmove_array
from coreweb.dashcore.utils.utils import load_fit
from coreweb.dashcore.utils.twist_plot import create_twist
from coreweb.dashcore.assets.config_sliders import modelslidervars, magslidervars
from coreweb.dashcore.app import update_launch_label, generate_graphstore
from coreweb.dashcore.pages.Start import update_alert_for_init

import pandas as pd
from IPython.display import display, HTML

import datetime

import warnings
warnings.filterwarnings('ignore')

import plotly.io as pio

# %% [markdown]
# ## Low Inclination Fluxropes

# %%
#from plotly.subplots import make_subplots


#fig = make_subplots(4,1,specs =[[{'type': 'scene'}],[{'type': 'scene'}],[{'type': 'scene'}],[{'type': 'scene'}]])
#fig = create_twist(fig,row=1,col=1,North_to_south = True,left_handed= False,resolution = 1000,turns = 10,line_thickness_red=20.0,red_arrow_thickness=1.3,black_arrow_thickness=1.3)
#fig = create_twist(fig,row=2,col=1,North_to_south = True,left_handed= True,resolution = 1000,turns = 10,line_thickness_red=20.0,red_arrow_thickness=1.3,black_arrow_thickness=1.3)
#fig = create_twist(fig,row=3,col=1,North_to_south = False,left_handed= True,resolution = 1000,turns = 10,line_thickness_red=20.0,red_arrow_thickness=1.3,black_arrow_thickness=1.3)
#fig = create_twist(fig,row=4,col=1,North_to_south = False,left_handed= False,resolution = 1000,turns = 10,line_thickness_red=20.0,red_arrow_thickness=1.3,black_arrow_thickness=1.3)
#fig.show()

# %%
modelstatevars = [0., # Longitude
                  0., # Latitude
                  0., # Inclination
                  0.3, # Diameter 1 AU 
                  2., # Aspect Ratio
                  20., # Launch Radius
                  600., # Launch Velocity
                  1.14, # Expansion Rate
                  1.00, # Background Drag
                  500., # Background Velocity
                  120., # T_Factor
                  1.64, # Magnetic Decay Rate
                  25., # Magnetic Field Strength 1 AU
                  ]

#figs = ropeplotter(modelstatevars,25)

fig = allropeplotter(modelstatevars,25)

#fig = create_twist(fig,row=1,col=2,North_to_south = True,left_handed= False,resolution = 1000,turns = 10,line_thickness_red=20.0,red_arrow_thickness=1.3,black_arrow_thickness=1.3)
#fig = create_twist(fig,row=2,col=2,North_to_south = True,left_handed= True,resolution = 1000,turns = 10,line_thickness_red=20.0,red_arrow_thickness=1.3,black_arrow_thickness=1.3)
#fig = create_twist(fig,row=3,col=2,North_to_south = False,left_handed= True,resolution = 1000,turns = 10,line_thickness_red=20.0,red_arrow_thickness=1.3,black_arrow_thickness=1.3)
#fig = create_twist(fig,row=4,col=2,North_to_south = False,left_handed= False,resolution = 1000,turns = 10,line_thickness_red=20.0,red_arrow_thickness=1.3,black_arrow_thickness=1.3)
    
#for fig in figs:
#    fig.show()

fig.show(config = {
  'toImageButtonOptions': {
    'format': 'svg'
  }
})


#### MOVE AU LABEL TO SIDE!!!!
# Out:
# righthanded: NES

# %% [markdown]
# ## High Inclination Fluxropes

# %%
modelstatevars = [0., # Longitude
                  0., # Latitude
                  90., # Inclination
                  0.3, # Diameter 1 AU 
                  2., # Aspect Ratio
                  20., # Launch Radius
                  600., # Launch Velocity
                  1.14, # Expansion Rate
                  1.00, # Background Drag
                  500., # Background Velocity
                  120., # T_Factor
                  1.64, # Magnetic Decay Rate
                  25., # Magnetic Field Strength 1 AU
                  ]


#figs = ropeplotter(modelstatevars,25)

fig = allropeplotter(modelstatevars,25)

#for fig in figs:
#    fig.show()

fig.show(config = {
  'toImageButtonOptions': {
    'format': 'svg'
  }
})
# Out:
# High Inclination!
# righthanded: ENW
